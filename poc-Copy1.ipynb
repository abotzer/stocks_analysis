# %%
import sys

# %%
import matplotlib.pyplot as plt
import seaborn

# %%
import yfinance as yf

# %%
ncr = yf.Ticker("NCR")

# %%
ncr.get_info()
# Out:
# {'zip': '30308',
#  'sector': 'Technology',
#  'fullTimeEmployees': 36000,
#  'longBusinessSummary': "NCR Corporation provides software and services worldwide. It operates through Banking, Retail, Hospitality, and Telecommunications and Technology segments. The Banking segment offers managed services and ATM-as-a-Service that allow banks to run their end-to-end ATM channels; software, services, and hardware, including interactive teller machines (ITM), as well as recycling, multi-function, and cash dispense ATMs; and digital banking solutions for financial institution's consumer and business customers. This segment also provides solutions for banking channel services, transaction processing, imaging, and branch services. The Retail segment provides solutions for retail industry comprising comprehensive API-point of sale (POS) retail software platforms and applications, hardware terminals, payment processing solutions, and bar-code scanners, as well as self-service kiosks, which consists of self-checkout (SCO). The Hospitality segment offers technology solutions to customers in the hospitality industry comprising table-service, quick-service, and fast casual restaurants. This segment provides cloud-based software applications for point-of-sale, back office, payment processing, kitchen production, restaurant management, and consumer engagement; and hospitality-oriented hardware products, such as POS terminals, order and payment kiosks, bar code scanners, printers, and peripherals. The Telecommunications and Technology segment offers maintenance, managed, and professional services using solutions comprises remote management and monitoring services for telecommunications and technology industry. The company also provides solutions for customer account opening and onboarding across digital, branch, and call center channels. NCR Corporation was founded in 1881 and is headquartered in Atlanta, Georgia.",
#  'city': 'Atlanta',
#  'phone': '937 445 1936',
#  'state': 'GA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.ncr.com',
#  'maxAge': 1,
#  'address1': '864 Spring Street Northwest',
#  'industry': 'Information Technology Services',
#  'ebitdaMargins': 0.12513,
#  'profitMargins': -0.02429,
#  'grossMargins': 0.27587998,
#  'operatingCashflow': 899000000,
#  'revenueGrowth': 0.196,
#  'operatingMargins': 0.08248,
#  'ebitda': 845000000,
#  'targetLowPrice': 50,
#  'recommendationKey': 'buy',
#  'grossProfits': 1674000000,
#  'freeCashflow': 1135500032,
#  'targetMedianPrice': 51,
#  'currentPrice': 40.87,
#  'earningsGrowth': -0.684,
#  'currentRatio': 1.016,
#  'returnOnAssets': 0.032509997,
#  'numberOfAnalystOpinions': 7,
#  'targetMeanPrice': 52.71,
#  'debtToEquity': 417.647,
#  'returnOnEquity': -0.059299998,
#  'targetHighPrice': 61,
#  'totalCash': 383000000,
#  'totalDebt': 6105999872,
#  'totalRevenue': 6752999936,
#  'totalCashPerShare': 2.902,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 51.807,
#  'quickRatio': 0.485,
#  'recommendationMean': 1.9,
#  'exchange': 'NYQ',
#  'shortName': 'NCR Corporation',
#  'longName': 'NCR Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'NCR',
#  'messageBoardId': 'finmb_169308',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.679,
#  'beta3Year': None,
#  'enterpriseToEbitda': 13.417,
#  '52WeekChange': 0.5552136,
#  'morningStarRiskRating': None,
#  'forwardEps': 3.51,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 132000000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 8.976,
#  'sharesShort': 7896325,
#  'sharesPercentSharesOut': 0.0598,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.93274003,
#  'netIncomeToCommon': -116000000,
#  'trailingEps': -1.447,
#  'lastDividendValue': 26.08,
#  'SandP52WeekChange': 0.3224138,
#  'priceToBook': 4.553253,
#  'heldPercentInsiders': 0.03396,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 6.29,
#  'sharesShortPreviousMonthDate': 1632960000,
#  'floatShares': 130097880,
#  'beta': 1.744935,
#  'enterpriseValue': 11337440256,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1106524800,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1191196800,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.613,
#  'priceToSalesTrailing12Months': 0.7988805,
#  'dateShortInterest': 1635465600,
#  'pegRatio': 4.29,
#  'ytdReturn': None,
#  'forwardPE': 11.643874,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0616,
#  'sharesShortPriorMonth': 8007727,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 40.42,
#  'regularMarketOpen': 41,
#  'twoHundredDayAverage': 42.0495,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 41.58,
#  'navPrice': None,
#  'averageDailyVolume10Day': 809570,
#  'regularMarketPreviousClose': 40.42,
#  'fiftyDayAverage': 41.2778,
#  'trailingAnnualDividendRate': None,
#  'open': 41,
#  'toCurrency': None,
#  'averageVolume10days': 809570,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 40.52,
#  'currency': 'USD',
#  'regularMarketVolume': 350426,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 5394840064,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 1005207,
#  'dayLow': 40.52,
#  'ask': 40.89,
#  'askSize': 800,
#  'volume': 350426,
#  'fiftyTwoWeekHigh': 50,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 25.61,
#  'bid': 40.85,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 800,
#  'dayHigh': 41.58,
#  'regularMarketPrice': 40.87,
#  'preMarketPrice': 41.5999,
#  'logo_url': 'https://logo.clearbit.com/ncr.com'}

# %%
hist
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2020-11-19  24.809999  26.070000  24.700001  26.000000  1143600          0
# 2020-11-20  25.830000  26.180000  25.610001  25.990000   753900          0
# 2020-11-23  26.420000  27.500000  26.350000  27.430000   988900          0
# 2020-11-24  28.010000  28.840000  27.559999  28.459999  1154300          0
# 2020-11-25  28.290001  28.870001  27.850000  28.520000   591400          0
# ...               ...        ...        ...        ...      ...        ...
# 2021-11-15  43.799999  43.980000  43.000000  43.020000   859600          0
# 2021-11-16  42.669998  43.130001  42.290001  42.320000  1160500          0
# 2021-11-17  41.959999  42.130001  40.900002  40.990002   716700          0
# 2021-11-18  40.990002  41.040001  40.060001  40.419998   635400          0
# 2021-11-19  41.000000  41.580002  40.520000  40.520000   197284          0
#
#             Stock Splits
# Date
# 2020-11-19             0
# 2020-11-20             0
# 2020-11-23             0
# 2020-11-24             0
# 2020-11-25             0
# ...                  ...
# 2021-11-15             0
# 2021-11-16             0
# 2021-11-17             0
# 2021-11-18             0
# 2021-11-19             0
#
# [253 rows x 7 columns]

# %%
# Plot everything by leveraging the very powerful matplotlib package
hist['Close'].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
hist['Close'].pct_change().plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
smoothed = hist['Close'].pct_change().rolling(window=5).sum()

# %%
smoothed.plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>
