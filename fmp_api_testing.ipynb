# %%
import pandas as pd
import requests
import json
bs = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?limit=120&apikey=c8a1f11f3091d8a5c3d5b7064ad45d19')
bs = bs.json()

# %%
bs = pd.DataFrame.from_dict(bs)
bs = bs.T
bs.columns = bs.iloc[0]

# %%
bs
# Out:
# date                                                                            2022-09-24  \
# date                                                                            2022-09-24
# symbol                                                                                AAPL
# reportedCurrency                                                                       USD
# cik                                                                             0000320193
# fillingDate                                                                     2022-10-28
# acceptedDate                                                           2022-10-27 18:01:14
# calendarYear                                                                          2022
# period                                                                                  FY
# cashAndCashEquivalents                                                         23646000000
# ...

# %% [markdown]
# # Flbooks

# %%
# %pip install fibooks
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for fibooks: filename=fibooks-2.0.4-py3-none-any.whl size=7224 sha256=d66ba0ba65531c75975acb2a5b43b6695526f99ebbb83c415322627fff2882e8
#   Stored in directory: /home/codespace/.cache/pip/wheels/f5/e6/a1/68f44c3d38ab716c5702c0ebaeabe1cdfbfdd04308fb38071c
# Successfully built fibooks
# ...

# %%
from fibooks import balance_sheet

tesla_bs = balance_sheet('tesla in 20222')

# %%
tesla_bs_df = tesla_bs.export_pandas()

# %%
tesla_bs_df.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
