# %%
import sys

# %%
# !{sys.executable} -m pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.64.tar.gz (26 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.9/site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/site-packages (from yfinance) (2.25.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.3-cp39-cp39-macosx_10_9_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 873 kB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.9/site-packages (from pandas>=0.24->yfinance) (2020.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->yfinance) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->yfinance) (1.26.2)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.64-py2.py3-none-any.whl size=24095 sha256=8d7e97f58bf5ac2791b2b564f1cfb0726765e9137add1fc31765a04b7a3f75ae
#   Stored in directory: /Users/AB185476/Library/Caches/pip/wheels/14/1e/2d/387bb238bef6f0c13ac61213e070fc2c8696c8e38fdc2935c9
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=7f969f075e1ec5e5f3a583206ebf4182f808d4d2081f78d07fe2ef4b3a8899dd
#   Stored in directory: /Users/AB185476/Library/Caches/pip/wheels/1d/13/0b/0c32509050dcd9264e9a90b1d9d2dc9c6db9538db151ea7d26
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, lxml, yfinance
#   WARNING: The script sample is installed in '/usr/local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed lxml-4.6.3 multitasking-0.0.9 yfinance-0.1.64
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import yfinance as yf

aer = yf.Ticker("AER")

# get historical market data
hist = ncr.history(period="1y", interval='1d')

# %%
aer.info
# Out:
# {'zip': 'D02 YX20',
#  'sector': 'Industrials',
#  'fullTimeEmployees': 376,
#  'longBusinessSummary': 'AerCap Holdings N.V. engages in the lease, financing, sale, and management of commercial aircraft and engines in Mainland China, Hong Kong, Macau, the United States, Ireland, and internationally. The company offers aircraft asset management services, such as remarketing aircraft; collecting rental and maintenance rent payments, monitoring aircraft maintenance, monitoring and enforcing contract compliance, and accepting delivery and redelivery of aircraft; and conducting ongoing lessee financial performance reviews. Its aircraft asset management services also include periodically inspecting the leased aircraft; coordinating technical modifications to aircraft to meet new lessee requirements; conducting restructuring negotiations in connection with lease defaults; repossessing aircraft; arranging and monitoring insurance coverage; registering and de-registering aircraft; arranging for aircraft and aircraft engine valuations; and providing market research services. The company also provides cash management services, including treasury services, such as the financing, refinancing, hedging, and ongoing cash management of vehicles; and administrative services comprising accounting and corporate secretarial services consisting of the preparation of budgets and financial statements. As of December 31, 2020, it had a portfolio of 1,330 owned, managed, or on order aircraft. AerCap Holdings N.V. was founded in 1995 and is headquartered in Dublin, Ireland.',
#  'city': 'Dublin',
#  'phone': '353 1 819 2010',
#  'country': 'Ireland',
#  'companyOfficers': [],
#  'website': 'http://www.aercap.com',
#  'maxAge': 1,
#  'address1': 'AerCap House',
#  'industry': 'Airports & Air Services',
#  'address2': '65 St. Stephenâ\x80\x99s Green',
#  'ebitdaMargins': 0.50236,
#  'profitMargins': -0.08197,
#  'grossMargins': 0.55814,
#  'operatingCashflow': 2365078016,
#  'revenueGrowth': -0.132,
#  'operatingMargins': 0.4973,
#  'ebitda': 2106366976,
#  'targetLowPrice': None,
#  'recommendationKey': 'none',
#  'grossProfits': 2524721000,
#  'freeCashflow': 1304961152,
#  'targetMedianPrice': None,
#  'currentPrice': 60.01,
#  'earningsGrowth': 0,
#  'currentRatio': 1.605,
#  'returnOnAssets': 0.029949998,
#  'numberOfAnalystOpinions': None,
#  'targetMeanPrice': None,
#  'debtToEquity': 299.041,
#  'returnOnEquity': -0.03596,
#  'targetHighPrice': None,
#  'totalCash': 1413300992,
#  'totalDebt': 28263913472,
#  'totalRevenue': 4192935936,
#  'totalCashPerShare': 11.031,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 32.797,
#  'quickRatio': 1.479,
#  'recommendationMean': None,
#  'exchange': 'NYQ',
#  'shortName': 'AerCap Holdings N.V.',
#  'longName': 'AerCap Holdings N.V.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AER',
#  'messageBoardId': 'finmb_896178',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.28,
#  'beta3Year': None,
#  'enterpriseToEbitda': 16.482,
#  '52WeekChange': 1.4514699,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.51,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 133379000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 73.238,
#  'sharesShort': 3516670,
#  'sharesPercentSharesOut': 0.026400002,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.97973996,
#  'netIncomeToCommon': -343675008,
#  'trailingEps': -2.7,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.40565026,
#  'priceToBook': 0.8193834,
#  'heldPercentInsiders': 0.03467,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': 4.58,
#  'sharesShortPreviousMonthDate': 1631664000,
#  'floatShares': 123500367,
#  'beta': 2.307407,
#  'enterpriseValue': 34717503488,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.015,
#  'priceToSalesTrailing12Months': 1.9089425,
#  'dateShortInterest': 1634256000,
#  'pegRatio': 0.89,
#  'ytdReturn': None,
#  'forwardPE': 9.218125,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0273,
#  'sharesShortPriorMonth': 3707628,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 60.87,
#  'regularMarketOpen': 60.66,
#  'twoHundredDayAverage': 56.223618,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 60.99,
#  'navPrice': None,
#  'averageDailyVolume10Day': 995800,
#  'regularMarketPreviousClose': 60.87,
#  'fiftyDayAverage': 58.836666,
#  'trailingAnnualDividendRate': None,
#  'open': 60.66,
#  'toCurrency': None,
#  'averageVolume10days': 995800,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 59.83,
#  'currency': 'USD',
#  'regularMarketVolume': 172000,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 8004073472,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 854576,
#  'dayLow': 59.83,
#  'ask': 60.32,
#  'askSize': 900,
#  'volume': 172000,
#  'fiftyTwoWeekHigh': 65.71,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 24.29,
#  'bid': 60.3,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 800,
#  'dayHigh': 60.99,
#  'regularMarketPrice': 60.01,
#  'preMarketPrice': 60.87,
#  'logo_url': 'https://logo.clearbit.com/aercap.com'}

# %%
hist
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2020-10-29  19.490000  20.629999  19.400000  20.309999  1245800          0
# 2020-10-30  20.000000  20.430000  19.959999  20.320000  1366800          0
# 2020-11-02  20.549999  20.719999  19.730000  19.809999  1686600          0
# 2020-11-03  20.309999  20.750000  20.020000  20.700001  1663100          0
# 2020-11-04  20.340000  20.809999  19.750000  20.000000   892400          0
# ...               ...        ...        ...        ...      ...        ...
# 2021-10-25  43.430000  43.730000  42.340000  42.430000  1607600          0
# 2021-10-26  42.869999  43.139999  41.209999  41.500000  2091100          0
# 2021-10-27  40.389999  41.360001  38.830002  40.200001  3177400          0
# 2021-10-28  40.009998  40.380001  39.169998  39.740002  1944000          0
# 2021-10-29  39.610001  39.930000  39.474998  39.740002   260165          0
#
#             Stock Splits
# Date
# 2020-10-29             0
# 2020-10-30             0
# 2020-11-02             0
# 2020-11-03             0
# 2020-11-04             0
# ...                  ...
# 2021-10-25             0
# 2021-10-26             0
# 2021-10-27             0
# 2021-10-28             0
# 2021-10-29             0
#
# [253 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn

# Plot everything by leveraging the very powerful matplotlib package
hist['Close'].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>
